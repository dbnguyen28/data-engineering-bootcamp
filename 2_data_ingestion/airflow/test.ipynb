# %%
import pandas as pandas
import pyarrow.parquet as pq

# %%
df = pq.read_table('fhv_tripdata_2019-03.parquet').to_pandas()
# Out:
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df = pq.read_table('fhv_tripdata_2019-03.parquet').to_pandas()
#
# File c:\Users\Don\anaconda3\Lib\site-packages\pyarrow\array.pxi:830, in pyarrow.lib._PandasConvertible.to_pandas()
#
# File c:\Users\Don\anaconda3\Lib\site-packages\pyarrow\table.pxi:3990, in pyarrow.lib.Table._to_pandas()
#
# File c:\Users\Don\anaconda3\Lib\site-packages\pyarrow\pandas_compat.py:820, in table_to_blockmanager(options, table, categories, ignore_metadata, types_mapper)
#     818 _check_data_column_metadata_consistency(all_columns)
#     819 columns = _deserialize_column_index(table, all_columns, column_indexes)
# --> 820 blocks = _table_to_blocks(options, table, categories, ext_columns_dtypes)
#     822 axes = [columns, index]
#     823 return BlockManager(blocks, axes)
#
# ...

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1         1  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2         1  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3         1  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4         2  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10         1.0                  N           142            43
# 1           0.20         1.0                  N           238           151
# 2          14.70         1.0                  N           132           165
# 3          10.60         1.0                  N           138           132
# 4           4.94         1.0                  N            68            33
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...
